# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import scipy.stats as stats
import statsmodels.api as sm
import seaborn as sns

sns.set_style('darkgrid')
# %matplotlib inline

import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('kc_house_data.csv', encoding='latin1')
df.head()
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0         NaN   0.0  ...      7        1180            0.0
# 1      7242     2.0         0.0   0.0  ...      7        2170          400.0
# 2     10000     1.0         0.0   0.0  ...      6         770            0.0
# 3      5000     1.0         0.0   0.0  ...      7        1050          910.0
# 4      8080     1.0         0.0   0.0  ...      8        1680            0.0
#
#   yr_built  yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15
# 0     1955           0.0    98178  47.5112 -122.257           1340        5650
# 1     1951        1991.0    98125  47.7210 -122.319           1690        7639
# 2     1933           NaN    98028  47.7379 -122.233           2720        8062
# 3     1965           0.0    98136  47.5208 -122.393           1360        5000
# 4     1987           0.0    98074  47.6168 -122.045           1800        7503
#
# [5 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21597 non-null  int64
#  1   date           21597 non-null  object
#  2   price          21597 non-null  float64
#  3   bedrooms       21597 non-null  int64
#  4   bathrooms      21597 non-null  float64
#  5   sqft_living    21597 non-null  int64
#  6   sqft_lot       21597 non-null  int64
#  7   floors         21597 non-null  float64
#  8   waterfront     19221 non-null  float64
#  9   view           21534 non-null  float64
#  10  condition      21597 non-null  int64
#  11  grade          21597 non-null  int64
#  12  sqft_above     21597 non-null  int64
#  13  sqft_basement  21597 non-null  object
#  14  yr_built       21597 non-null  int64
#  15  yr_renovated   17755 non-null  float64
#  16  zipcode        21597 non-null  int64
#  17  lat            21597 non-null  float64
#  18  long           21597 non-null  float64
#  19  sqft_living15  21597 non-null  int64
#  20  sqft_lot15     21597 non-null  int64
# dtypes: float64(8), int64(11), object(2)
# memory usage: 3.5+ MB

# %%
df['waterfront'].value_counts()
# Out:
# 0.0    19075
# 1.0      146
# Name: waterfront, dtype: int64

# %%
#separate numerical data from the data set
numerical_data = df.select_dtypes(include = 'number').describe()
#descriptive statistics for quantitative variables
numerical_data.drop(['id','waterfront','zipcode'],axis =1).describe()
# Out:
#               price      bedrooms     bathrooms   sqft_living      sqft_lot  \
# count  8.000000e+00      8.000000      8.000000      8.000000  8.000000e+00
# mean   1.265533e+06   2705.662437   2701.860601   5549.428497  2.191664e+05
# std    2.608586e+06   7633.260597   7634.789613   7754.222939  5.788317e+05
# min    2.159700e+04      0.926299      0.500000    370.000000  5.200000e+02
# 25%    2.610000e+05      2.500000      1.504746   1302.026531  6.973500e+03
# 50%    4.086841e+05      3.186600      2.182913   1995.160925  1.289220e+04
# 75%    5.664724e+05     11.250000      3.875000   5297.500000  2.655091e+04
# max    7.700000e+06  21597.000000  21597.000000  21597.000000  1.651359e+06
#
#              floors          view     condition         grade    sqft_above  \
# count      8.000000      8.000000      8.000000      8.000000      8.000000
# mean    2701.004222   2692.374944   2702.132546   2705.478889   4869.169575
# std     7635.135339   7613.166320   7634.679511   7633.328060   7349.081333
# min        0.539683      0.000000      0.650546      1.173200    370.000000
# 25%        1.000000      0.000000      2.500000      6.000000   1099.439940
# 50%        1.497048      0.116931      3.204913      7.328958   1674.298421
# 75%        2.375000      1.574265      4.250000      9.250000   4010.000000
# max    21597.000000  21534.000000  21597.000000  21597.000000  21597.000000
#
#            yr_built  yr_renovated           lat          long  sqft_living15  \
# count      8.000000      8.000000      8.000000      8.000000       8.000000
# mean    4179.421864   2531.697899   2735.294131   2608.051093    4570.981349
# std     7070.470127   6189.752456   7621.298120   7672.813309    7107.282454
# min       29.375234      0.000000      0.138552   -122.519000     399.000000
# 25%     1938.250000      0.000000     47.392300   -122.255250    1288.807618
# 50%     1972.999838     41.818389     47.565946   -122.169491    1913.310159
# 75%     2001.500000    803.709810     47.702900    -90.951069    3322.500000
# max    21597.000000  17755.000000  21597.000000  21597.000000   21597.000000
#
#           sqft_lot15
# count       8.000000
# mean   119535.465683
# std    303841.801891
# min       651.000000
# 25%      6990.000000
# 50%     11420.641756
# 75%     23016.360488
# max    871200.000000

# %%
df['bedrooms'].describe()
# Out:
# count    21597.000000
# mean         3.373200
# std          0.926299
# min          1.000000
# 25%          3.000000
# 50%          3.000000
# 75%          4.000000
# max         33.000000
# Name: bedrooms, dtype: float64

# %%
df['bedrooms'].value_counts()
# Out:
# 3     9824
# 4     6882
# 2     2760
# 5     1601
# 6      272
# 1      196
# 7       38
# 8       13
# 9        6
# 10       3
# 11       1
# 33       1
# Name: bedrooms, dtype: int64

# %%
df.dtypes
# Out:
# id                 int64
# date              object
# price            float64
# bedrooms           int64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront       float64
# view             float64
# condition          int64
# grade              int64
# sqft_above         int64
# sqft_basement     object
# yr_built           int64
# yr_renovated     float64
# zipcode            int64
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15         int64
# dtype: object

# %%
df.sqft_basement = df.sqft_basement.replace(['?'],'0')
df['sqft_basement'] = df['sqft_basement'].astype('float')

# %%
df['sqft_basement'].value_counts()
# Out:
# 0.0       13280
# 600.0       217
# 500.0       209
# 700.0       208
# 800.0       201
#           ...
# 915.0         1
# 295.0         1
# 1281.0        1
# 2130.0        1
# 906.0         1
# Name: sqft_basement, Length: 303, dtype: int64

# %%
#Data cleaning

# %%
##Removing null values

# %%
#Checking for null values
df.isnull().sum()
# Out:
# id                  0
# date                0
# price               0
# bedrooms            0
# bathrooms           0
# sqft_living         0
# sqft_lot            0
# floors              0
# waterfront       2376
# view               63
# condition           0
# grade               0
# sqft_above          0
# sqft_basement       0
# yr_built            0
# yr_renovated     3842
# zipcode             0
# lat                 0
# long                0
# sqft_living15       0
# sqft_lot15          0
# dtype: int64

# %%
df.view.describe()
# Out:
# count    21534.000000
# mean         0.233863
# std          0.765686
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          4.000000
# Name: view, dtype: float64

# %%
df['view'] = df.view.fillna(value = df.view.median())
df.view.value_counts()
# Out:
# 0.0    19485
# 2.0      957
# 3.0      508
# 1.0      330
# 4.0      317
# Name: view, dtype: int64

# %%
df.waterfront.describe()
# Out:
# count    19221.000000
# mean         0.007596
# std          0.086825
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          1.000000
# Name: waterfront, dtype: float64

# %%
df.waterfront = df['waterfront'].fillna(value = df.waterfront.median())

# %%
df
# Out:
#                id        date     price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520  10/13/2014  221900.0         3       1.00         1180
# 1      6414100192   12/9/2014  538000.0         3       2.25         2570
# 2      5631500400   2/25/2015  180000.0         2       1.00          770
# 3      2487200875   12/9/2014  604000.0         4       3.00         1960
# 4      1954400510   2/18/2015  510000.0         3       2.00         1680
# ...           ...         ...       ...       ...        ...          ...
# 21592   263000018   5/21/2014  360000.0         3       2.50         1530
# 21593  6600060120   2/23/2015  400000.0         4       2.50         2310
# 21594  1523300141   6/23/2014  402101.0         2       0.75         1020
# 21595   291310100   1/16/2015  400000.0         3       2.50         1600
# 21596  1523300157  10/15/2014  325000.0         2       0.75         1020
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 0          5650     1.0         0.0   0.0  ...      7        1180
# 1          7242     2.0         0.0   0.0  ...      7        2170
# 2         10000     1.0         0.0   0.0  ...      6         770
# 3          5000     1.0         0.0   0.0  ...      7        1050
# 4          8080     1.0         0.0   0.0  ...      8        1680
# ...         ...     ...         ...   ...  ...    ...         ...
# 21592      1131     3.0         0.0   0.0  ...      8        1530
# 21593      5813     2.0         0.0   0.0  ...      8        2310
# 21594      1350     2.0         0.0   0.0  ...      7        1020
# 21595      2388     2.0         0.0   0.0  ...      8        1600
# 21596      1076     2.0         0.0   0.0  ...      7        1020
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 0                0.0      1955           0.0    98178  47.5112 -122.257
# 1              400.0      1951        1991.0    98125  47.7210 -122.319
# 2                0.0      1933           NaN    98028  47.7379 -122.233
# 3              910.0      1965           0.0    98136  47.5208 -122.393
# 4                0.0      1987           0.0    98074  47.6168 -122.045
# ...              ...       ...           ...      ...      ...      ...
# 21592            0.0      2009           0.0    98103  47.6993 -122.346
# 21593            0.0      2014           0.0    98146  47.5107 -122.362
# 21594            0.0      2009           0.0    98144  47.5944 -122.299
# 21595            0.0      2004           0.0    98027  47.5345 -122.069
# 21596            0.0      2008           0.0    98144  47.5941 -122.299
#
#        sqft_living15  sqft_lot15
# 0               1340        5650
# 1               1690        7639
# 2               2720        8062
# 3               1360        5000
# 4               1800        7503
# ...              ...         ...
# 21592           1530        1509
# 21593           1830        7200
# 21594           1020        2007
# 21595           1410        1287
# 21596           1020        1357
#
# [21597 rows x 21 columns]

# %%
df.yr_renovated = df.yr_renovated.fillna(value = df.yr_renovated.median())

# %%
df.yr_renovated.value_counts()
# Out:
# 0.0       20853
# 2014.0       73
# 2003.0       31
# 2013.0       31
# 2007.0       30
#           ...
# 1946.0        1
# 1959.0        1
# 1971.0        1
# 1951.0        1
# 1954.0        1
# Name: yr_renovated, Length: 70, dtype: int64

# %%
df.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
df.sqft_basement.describe()
# Out:
# count    21597.000000
# mean       285.716581
# std        439.819830
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%        550.000000
# max       4820.000000
# Name: sqft_basement, dtype: float64

# %%
df.sqft_basement.value_counts()
# Out:
# 0.0       13280
# 600.0       217
# 500.0       209
# 700.0       208
# 800.0       201
#           ...
# 915.0         1
# 295.0         1
# 1281.0        1
# 2130.0        1
# 906.0         1
# Name: sqft_basement, Length: 303, dtype: int64

# %% [markdown]
# Majority of the houses have not been viewed

# %%
#fig, ax = plt.subplots(figsize = (8,6))
#ax.scatter(x = df['sqft_living'], y = df['price'])
sns.barplot(y='price',x ='grade',data=df)
# Out:
# <AxesSubplot:xlabel='grade', ylabel='price'>

# %%
#Checking for columns that correlate with price
fig , ax = plt.subplots(figsize=(10,9))
ax = sns.heatmap(df.corr(),annot=True, linewidths = 1)

# %%
#list of column index and column names
list(enumerate(df))
df_l =  [df['grade'],df['bedrooms'],df['floors'],df['view'],df['condition'],df['bathrooms'],df['sqft_living'],df['sqft_living15']]

# %%
#univariate analysis
sns.set_style('darkgrid')
plt.figure(figsize=(16,14))
for i in enumerate(df_l):
    plt.subplot(2,4,i[0]+1)
    sns.countplot(i[1])

# %%
df_b = [df['grade'],df['bedrooms'],df['floors'],df['view'],df['condition'],df['bathrooms'],df['sqft_living'],df['sqft_living15']]

# %%
sns.set_style('darkgrid')
plt.figure(figsize=(16,14))
for i in enumerate(df_l):
    plt.subplot(2,4,i[0]+1)
    sns.boxplot(i[1])
#sns.boxplot(data = df,x = 'bedrooms',y = 'price')

# %%
df_s = [df['grade'],df['bedrooms'],df['floors'],df['view'],df['condition'],df['bathrooms'],df['sqft_living'],df['sqft_living15']]

# %%
sns.set_style('darkgrid')
plt.figure(figsize=(16,14))
for i in enumerate(df_s):
    plt.subplot(2,4,i[0]+1)
    sns.scatterplot(i[1],df['price'])

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(data = df,x = df['long'], y = df['lat'], hue = df['price'], palette ='gist_stern')
# Out:
# <AxesSubplot:xlabel='long', ylabel='lat'>

# %%
#The relationship between year built and price
fig, ax = plt.subplots(figsize= (10,5))
ax.scatter(x = df['sqft_basement'],y= df['price'])
plt.xlabel("grade")
plt.ylabel("price")
plt.title("relationship between year built and price")
# Out:
# Text(0.5, 1.0, 'relationship between year built and price')

# %%
#What affects price the most
df.corr()['price'].sort_values(ascending=False).drop('price').plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
#What price range for most house
sns.set_style('darkgrid')


sns.distplot(df['price'])
# Out:
# <AxesSubplot:xlabel='price', ylabel='Density'>

# %%
#How many bedrooms do most houses have?
plt.figure(figsize = (10,8))
sns.countplot(df.bedrooms, order = df['bedrooms'].value_counts().index)
# Out:
# <AxesSubplot:xlabel='bedrooms', ylabel='count'>

# %%
#Drop outlier
#df.dropna(subset = (['bedrooms'] >= 11),inplace = True, index =0 )

df.drop(df.loc[df['bedrooms'] >=11].index, inplace=True)
df['bedrooms'].value_counts()
# Out:
# 3     9824
# 4     6882
# 2     2760
# 5     1601
# 6      272
# 1      196
# 7       38
# 8       13
# 9        6
# 10       3
# Name: bedrooms, dtype: int64

# %%
#converting date
df['date'] = pd.to_datetime(df['date'])

# %%
df['months'] = df['date'].dt.month
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21595 entries, 0 to 21596
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21595 non-null  int64
#  1   date           21595 non-null  datetime64[ns]
#  2   price          21595 non-null  float64
#  3   bedrooms       21595 non-null  int64
#  4   bathrooms      21595 non-null  float64
#  5   sqft_living    21595 non-null  int64
#  6   sqft_lot       21595 non-null  int64
#  7   floors         21595 non-null  float64
#  8   waterfront     21595 non-null  float64
#  9   view           21595 non-null  float64
#  10  condition      21595 non-null  int64
#  11  grade          21595 non-null  int64
#  12  sqft_above     21595 non-null  int64
#  13  sqft_basement  21595 non-null  float64
#  14  yr_built       21595 non-null  int64
#  15  yr_renovated   21595 non-null  float64
#  16  zipcode        21595 non-null  int64
#  17  lat            21595 non-null  float64
#  18  long           21595 non-null  float64
#  19  sqft_living15  21595 non-null  int64
#  20  sqft_lot15     21595 non-null  int64
#  21  months         21595 non-null  int64
# dtypes: datetime64[ns](1), float64(9), int64(12)
# memory usage: 3.8 MB

# %%
#waterfront effect on size
plt.figure(figsize=(10,8))
sns.scatterplot(data = df, x = df.date, y = df.price, hue = 'waterfront')
# Out:
# <AxesSubplot:xlabel='date', ylabel='price'>

# %%
#houses with a waterfront have high prices compared to those without

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(data = df, x = df.date, y = df.price, hue = 'view')
# Out:
# <AxesSubplot:xlabel='date', ylabel='price'>

# %%
#low priced housed do not get a lot of views as compared to expensive houses

# %% [markdown]
# ### categorical data

# %%
df.head(3)
# Out:
#            id       date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520 2014-10-13  221900.0         3       1.00         1180
# 1  6414100192 2014-12-09  538000.0         3       2.25         2570
# 2  5631500400 2015-02-25  180000.0         2       1.00          770
#
#    sqft_lot  floors  waterfront  view  ...  sqft_above  sqft_basement  \
# 0      5650     1.0         0.0   0.0  ...        1180            0.0
# 1      7242     2.0         0.0   0.0  ...        2170          400.0
# 2     10000     1.0         0.0   0.0  ...         770            0.0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1955           0.0    98178  47.5112 -122.257           1340
# 1      1951        1991.0    98125  47.7210 -122.319           1690
# 2      1933           0.0    98028  47.7379 -122.233           2720
#
#    sqft_lot15  months
# 0        5650      10
# 1        7639      12
# 2        8062       2
#
# [3 rows x 22 columns]

# %%
num_df = df[['price','bathrooms','bedrooms','sqft_living','sqft_above','lat','long','sqft_living15','sqft_lot15']]
cat_df = df[['condition','grade','yr_built','view','yr_renovated','zipcode']]

# %%
cat_df.view.value_counts()
# Out:
# 0.0    19483
# 2.0      957
# 3.0      508
# 1.0      330
# 4.0      317
# Name: view, dtype: int64

# %%
bins =[0,1,4]
bin_views = pd.cut(cat_df['view'], bins,include_lowest = True, labels = ['no_views', 'viewed'] )
bin_views = bin_views.cat.as_unordered()

# %%
bin_views.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
bin_views.value_counts()
# Out:
# no_views    19813
# viewed       1782
# Name: view, dtype: int64

# %% [markdown]
# # checking on year of renovation

# %%
df.yr_renovated.value_counts()
# Out:
# 0.0       20852
# 2014.0       73
# 2003.0       31
# 2013.0       31
# 2007.0       30
#           ...
# 1934.0        1
# 1971.0        1
# 1954.0        1
# 1950.0        1
# 1944.0        1
# Name: yr_renovated, Length: 70, dtype: int64

# %%
df.yr_renovated.isnull().value_counts()
# Out:
# False    21595
# Name: yr_renovated, dtype: int64

# %%
not_renovated = (df['yr_renovated'] == 0)
df['not_renovated'] = not_renovated
df.not_renovated
# Out:
#                id       date      price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520 2014-10-13   221900.0         3       1.00         1180
# 2      5631500400 2015-02-25   180000.0         2       1.00          770
# 3      2487200875 2014-12-09   604000.0         4       3.00         1960
# 4      1954400510 2015-02-18   510000.0         3       2.00         1680
# 5      7237550310 2014-05-12  1230000.0         4       4.50         5420
# ...           ...        ...        ...       ...        ...          ...
# 21592   263000018 2014-05-21   360000.0         3       2.50         1530
# 21593  6600060120 2015-02-23   400000.0         4       2.50         2310
# 21594  1523300141 2014-06-23   402101.0         2       0.75         1020
# 21595   291310100 2015-01-16   400000.0         3       2.50         1600
# 21596  1523300157 2014-10-15   325000.0         2       0.75         1020
#
#        sqft_lot  floors  waterfront  view  ...  sqft_above  sqft_basement  \
# 0          5650     1.0         0.0   0.0  ...        1180            0.0
# 2         10000     1.0         0.0   0.0  ...         770            0.0
# 3          5000     1.0         0.0   0.0  ...        1050          910.0
# 4          8080     1.0         0.0   0.0  ...        1680            0.0
# 5        101930     1.0         0.0   0.0  ...        3890         1530.0
# ...         ...     ...         ...   ...  ...         ...            ...
# 21592      1131     3.0         0.0   0.0  ...        1530            0.0
# 21593      5813     2.0         0.0   0.0  ...        2310            0.0
# 21594      1350     2.0         0.0   0.0  ...        1020            0.0
# 21595      2388     2.0         0.0   0.0  ...        1600            0.0
# 21596      1076     2.0         0.0   0.0  ...        1020            0.0
#
#        yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0          1955           0.0    98178  47.5112 -122.257           1340
# 2          1933           0.0    98028  47.7379 -122.233           2720
# 3          1965           0.0    98136  47.5208 -122.393           1360
# 4          1987           0.0    98074  47.6168 -122.045           1800
# 5          2001           0.0    98053  47.6561 -122.005           4760
# ...         ...           ...      ...      ...      ...            ...
# 21592      2009           0.0    98103  47.6993 -122.346           1530
# 21593      2014           0.0    98146  47.5107 -122.362           1830
# 21594      2009           0.0    98144  47.5944 -122.299           1020
# 21595      2004           0.0    98027  47.5345 -122.069           1410
# 21596      2008           0.0    98144  47.5941 -122.299           1020
#
#        sqft_lot15  months
# 0            5650      10
# 2            8062       2
# 3            5000      12
# 4            7503       2
# 5          101930       5
# ...           ...     ...
# 21592        1509       5
# 21593        7200       2
# 21594        2007       6
# 21595        1287       1
# 21596        1357      10
#
# [20852 rows x 22 columns]

# %%
df.yr_renovated.describe()
# Out:
# count    21595.000000
# mean        68.672007
# std        363.816998
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max       2015.000000
# Name: yr_renovated, dtype: float64
